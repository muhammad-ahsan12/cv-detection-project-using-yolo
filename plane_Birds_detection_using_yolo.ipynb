# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.8/921.8 kB 25.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 99.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="NwOq8YGFjNY57lbPrwBo")
project = rf.workspace("ahsan-h6w1d").project("aerial-dnfye-eudya")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 13.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Aerial--1 in yolov8:: 100%|██████████| 560/560 [00:00<00:00, 5265.75it/s]

# %%
from ultralytics import YOLO

# Load the model
model = YOLO('yolov8n.pt')

# Train it
model.train(data='/content/Aerial--1/data.yaml', epochs=50, imgsz=640, patience=10)
# Out:
# Ultralytics 8.3.79 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model.predict(source='/content/Aerial--1/test/images', save=True)
# Out:
# image 1/11 /content/Aerial--1/test/images/09____Romain_Courtemanche_jpg.rf.bdf6011e12eab12b293cc4c6fedc1b70.jpg: 512x640 1 Airplane, 36.2ms
# image 2/11 /content/Aerial--1/test/images/172343774-GnLAXp9B_jpg.rf.25925bed369325e7ae8e19e317890dfb.jpg: 352x640 6 Birds, 38.9ms
# image 3/11 /content/Aerial--1/test/images/OIP-35-_jpg.rf.6099598104fe200195451b50b2efdb90.jpg: 448x640 2 Helicopters, 90.4ms
# image 4/11 /content/Aerial--1/test/images/OIP-36-_jpg.rf.50831677e220e91bf51ca4796049192d.jpg: 480x640 1 Helicopter, 146.3ms
# image 5/11 /content/Aerial--1/test/images/OIP-4-_jpg.rf.82e9aac6498ab887ca857c10904c7d4e.jpg: 448x640 1 Airplane, 20.6ms
# image 6/11 /content/Aerial--1/test/images/OIP-9-_jpg.rf.970c47dd41a21b6b308bc73c069a88fb.jpg: 416x640 2 Airplanes, 1 Helicopter, 104.0ms
# image 7/11 /content/Aerial--1/test/images/R-4-_jpg.rf.5f7af237727a5a8c8b16fe146d1f1697.jpg: 288x640 2 Airplanes, 3 Birds, 75.6ms
# ...

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO('runs/detect/train/weights/best.pt')

# Run inference on test images
results = model.predict(
    source='/content/Aerial--1/test/images',  # Path to test images
    conf=0.25,                                 # Confidence threshold
    iou=0.45,                                  # IoU threshold for NMS
    save=True,                                 # Save output images
    save_txt=True                              # Save predictions as .txt files
)

# Print results
for result in results:
    print(f"Image: {result.path}")
    print(f"Detections: {len(result.boxes)}")
    print(f"Classes: {result.boxes.cls.tolist()}")
    print(f"Confidences: {result.boxes.conf.tolist()}")
    print("---")
# Out:
# image 1/11 /content/Aerial--1/test/images/09____Romain_Courtemanche_jpg.rf.bdf6011e12eab12b293cc4c6fedc1b70.jpg: 512x640 1 Helicopter, 9.2ms
# image 2/11 /content/Aerial--1/test/images/172343774-GnLAXp9B_jpg.rf.25925bed369325e7ae8e19e317890dfb.jpg: 352x640 7 Birds, 9.2ms
# image 3/11 /content/Aerial--1/test/images/OIP-35-_jpg.rf.6099598104fe200195451b50b2efdb90.jpg: 448x640 1 Helicopter, 30.7ms
# image 4/11 /content/Aerial--1/test/images/OIP-36-_jpg.rf.50831677e220e91bf51ca4796049192d.jpg: 480x640 1 Helicopter, 11.8ms
# image 5/11 /content/Aerial--1/test/images/OIP-4-_jpg.rf.82e9aac6498ab887ca857c10904c7d4e.jpg: 448x640 1 Airplane, 14.3ms
# image 6/11 /content/Aerial--1/test/images/OIP-9-_jpg.rf.970c47dd41a21b6b308bc73c069a88fb.jpg: 416x640 1 Airplane, 16.9ms
# image 7/11 /content/Aerial--1/test/images/R-4-_jpg.rf.5f7af237727a5a8c8b16fe146d1f1697.jpg: 288x640 4 Birds, 33.0ms
# ...

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import numpy as np

# Load your trained model
model = YOLO('runs/detect/train/weights/best.pt')

# Path to your single image
image_path = '/content/Aerial--1/test/images/three-silhouettes-frigate-birds-flying-against-blue-sky-fluffy-white-clouds-138967898_jpg.rf.8e54583033246d2b3d1ac65264276baa.jpg' # Replace with your image path

# Run inference
results = model.predict(
    source=image_path,
    conf=0.25,  # Confidence threshold
    iou=0.45,   # IoU threshold for NMS
    save=False  # We’ll handle displaying manually
)

# Get the first result (since it’s one image)
result = results[0]

# Load the original image with OpenCV
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for display

# Draw detections on the image
for box in result.boxes:
    # Get box coordinates, class, and confidence
    x1, y1, x2, y2 = map(int, box.xyxy[0])  # Bounding box coordinates
    class_id = int(box.cls[0])              # Class ID (0=Airplane, 1=Bird, 2=Helicopter)
    confidence = box.conf[0]                # Confidence score
    label = f"{result.names[class_id]} {confidence:.2f}"  # e.g., "Helicopter 0.87"

    # Draw rectangle and label
    cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)  # Green box
    cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Display the image with detections
plt.figure(figsize=(10, 10))
plt.imshow(image)
plt.axis('off')  # Hide axes
plt.title('Detected Objects')
plt.show()

# Print detection details
print(f"Image: {image_path}")
print(f"Number of detections: {len(result.boxes)}")
for box in result.boxes:
    class_id = int(box.cls[0])
    confidence = box.conf[0]
    print(f" - {result.names[class_id]} (Confidence: {confidence:.2f})")
# Out:
# image 1/1 /content/Aerial--1/test/images/three-silhouettes-frigate-birds-flying-against-blue-sky-fluffy-white-clouds-138967898_jpg.rf.8e54583033246d2b3d1ac65264276baa.jpg: 480x640 3 Birds, 6.8ms
# Speed: 2.2ms preprocess, 6.8ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Image: /content/Aerial--1/test/images/three-silhouettes-frigate-birds-flying-against-blue-sky-fluffy-white-clouds-138967898_jpg.rf.8e54583033246d2b3d1ac65264276baa.jpg
# Number of detections: 3
#  - Bird (Confidence: 0.79)
#  - Bird (Confidence: 0.69)
#  - Bird (Confidence: 0.56)
